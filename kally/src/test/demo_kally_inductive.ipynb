# %% [markdown]
# ### Prepare Relevant imports

# %%
import torch.optim as optim 
import torch.nn as nn
import torch_geometric as tg
import sklearn.metrics as metrics
import torch

import sys
import os
import time

gat_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(gat_path)
from gat import GAT_Inductive

# %% [markdown]
# ### Preparing the data (the unique graph)

# %%
train_dataset = tg.datasets.PPI(root='data', split='train')
val_dataset = tg.datasets.PPI(root='data', split='val')
test_dataset = tg.datasets.PPI(root='data', split='test')

train_loader = tg.loader.DataLoader(train_dataset, batch_size=2, shuffle=True)
val_loader = tg.loader.DataLoader(val_dataset, batch_size=2)
test_loader = tg.loader.DataLoader(test_dataset, batch_size=2)

# for simplicity later on we just cache those
val_graph_pair = next(iter(val_loader))
test_graph_pair = next(iter(test_loader))

nodes_val = val_graph_pair.x
y_val = val_graph_pair.y
adjacency_val = tg.utils.to_dense_adj(val_graph_pair.edge_index).squeeze(dim=0)

nodes_test = test_graph_pair.x
y_test = test_graph_pair.y
adjacency_test = tg.utils.to_dense_adj(test_graph_pair.edge_index).squeeze(dim=0)

# %% [markdown]
# ### Preparing Model and Optimisers

# %%
# default values from GAT paper
lr = 0.005
weight_decay = 0.0005

ind_model = GAT_Inductive(50, 121)
criterion = nn.CrossEntropyLoss()
optimiser = optim.Adam(ind_model.parameters(), 
                       lr=lr, 
                       weight_decay=weight_decay)

# %% [markdown]
# ### Running training with (very) simple early stopping with 10 epochs tolerance

# %%
tolerance = 0
best_val_f1 = 0

for epoch in range(50):
    ind_model.train()
    start_time = time.time()
    
    for train_graph_pair in train_loader:
        nodes_train = train_graph_pair.x
        y_train = train_graph_pair.y
        adjacency_train = tg.utils.to_dense_adj(train_graph_pair.edge_index, max_num_nodes=nodes_train.shape[0]).squeeze(dim=0)
    
        output = ind_model(nodes_train, adjacency_train)
        loss = criterion(output, y_train)
    
        optimiser.zero_grad()
        loss.backward()
        optimiser.step()
    
    # compute validation micro f1-score to fascilitate early stopping if needed
    ind_model.eval()
    with torch.no_grad():
        output = ind_model(nodes_val, adjacency_val)
        output_labeled = torch.where(output > 0.5, 1.0, 0.0)
        current_val_f1 = metrics.f1_score(output_labeled, y_val, average='micro')
    
    if current_val_f1 > best_val_f1:
        best_val_f1 = current_val_f1
        tolerance = 0
        print(f'EPOCH {epoch+1} improved validation micro f1-score to: {current_val_f1}')
        
        with torch.no_grad():
            output = ind_model(nodes_test, adjacency_test)
            output_labeled = torch.where(output > 0.5, 1.0, 0.0)
            test_f1 = metrics.f1_score(output_labeled, y_test, average='micro')
            print(f'PRINTING TEST MICRO F1-SCORE: {test_f1}')
        print('SAVING MODEL to ind_model.pt')
        torch.save(ind_model.state_dict(), 'ind_model.pt')
        
    else:
        tolerance += 1
        print(f'EPOCH {epoch+1} did not improve validation micro f1-score')
        
        if tolerance == 19:
            print('Tolerance 20 epochs reached, exiting')
            break
    end_time = time.time()
    print('Seconds taken for this epoch: {:.4f}s'.format(end_time - start_time))
    print('----------------------------------------------- \n')
# Out:
# EPOCH 1 improved validation micro f1-score to: 0.49921082990921806
# PRINTING TEST MICRO F1-SCORE: 0.503750089531469
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 182.7012s
# -----------------------------------------------
#
# EPOCH 2 did not improve validation micro f1-score
# Seconds taken for this epoch: 163.8051s
# -----------------------------------------------
#
# EPOCH 3 improved validation micro f1-score to: 0.5157148060300792
# PRINTING TEST MICRO F1-SCORE: 0.5180258538973553
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 171.8168s
# -----------------------------------------------
#
# EPOCH 4 improved validation micro f1-score to: 0.5300411591838794
# PRINTING TEST MICRO F1-SCORE: 0.5346166062208697
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 173.5455s
# -----------------------------------------------
#
# EPOCH 5 improved validation micro f1-score to: 0.5382811652494639
# PRINTING TEST MICRO F1-SCORE: 0.5428615347828315
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 134.0979s
# -----------------------------------------------
#
# EPOCH 6 improved validation micro f1-score to: 0.555733542170962
# PRINTING TEST MICRO F1-SCORE: 0.5623259870907716
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 100.1656s
# -----------------------------------------------
#
# EPOCH 7 improved validation micro f1-score to: 0.5673988174919711
# PRINTING TEST MICRO F1-SCORE: 0.5737628211661585
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 95.1686s
# -----------------------------------------------
#
# EPOCH 8 improved validation micro f1-score to: 0.5766835797911197
# PRINTING TEST MICRO F1-SCORE: 0.5857705130579738
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 97.5591s
# -----------------------------------------------
#
# EPOCH 9 did not improve validation micro f1-score
# Seconds taken for this epoch: 95.5877s
# -----------------------------------------------
#
# EPOCH 10 improved validation micro f1-score to: 0.5928863918835204
# PRINTING TEST MICRO F1-SCORE: 0.6021738783458094
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 107.6469s
# -----------------------------------------------
#
# EPOCH 11 improved validation micro f1-score to: 0.5965805747544561
# PRINTING TEST MICRO F1-SCORE: 0.6067159082171272
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 110.4809s
# -----------------------------------------------
#
# EPOCH 12 improved validation micro f1-score to: 0.6022622692643619
# PRINTING TEST MICRO F1-SCORE: 0.6129180779242093
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 107.2382s
# -----------------------------------------------
#
# EPOCH 13 improved validation micro f1-score to: 0.6133131288001297
# PRINTING TEST MICRO F1-SCORE: 0.6269030147643886
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 104.0784s
# -----------------------------------------------
#
# EPOCH 14 improved validation micro f1-score to: 0.6146770864917205
# PRINTING TEST MICRO F1-SCORE: 0.6254301189586149
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 105.6719s
# -----------------------------------------------
#
# EPOCH 15 improved validation micro f1-score to: 0.6229585296103285
# PRINTING TEST MICRO F1-SCORE: 0.6346224163492158
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 101.6700s
# -----------------------------------------------
#
# EPOCH 16 improved validation micro f1-score to: 0.6274147975153066
# PRINTING TEST MICRO F1-SCORE: 0.6402729278504543
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 110.5787s
# -----------------------------------------------
#
# EPOCH 17 improved validation micro f1-score to: 0.631449682510594
# PRINTING TEST MICRO F1-SCORE: 0.6462173017348545
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 106.1044s
# -----------------------------------------------
#
# EPOCH 18 improved validation micro f1-score to: 0.6320364525861737
# PRINTING TEST MICRO F1-SCORE: 0.6461068509691197
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 106.5115s
# -----------------------------------------------
#
# EPOCH 19 improved validation micro f1-score to: 0.6437717037005475
# PRINTING TEST MICRO F1-SCORE: 0.6596953812234246
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 109.5677s
# -----------------------------------------------
#
# EPOCH 20 improved validation micro f1-score to: 0.6497177293401495
# PRINTING TEST MICRO F1-SCORE: 0.6669183015533273
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 104.6233s
# -----------------------------------------------
#
# EPOCH 21 did not improve validation micro f1-score
# Seconds taken for this epoch: 104.2821s
# -----------------------------------------------
#
# EPOCH 22 improved validation micro f1-score to: 0.6520847183968087
# PRINTING TEST MICRO F1-SCORE: 0.6677360534752487
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 103.6531s
# -----------------------------------------------
#
# EPOCH 23 improved validation micro f1-score to: 0.6562536699941279
# PRINTING TEST MICRO F1-SCORE: 0.6744074752834437
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 104.1490s
# -----------------------------------------------
#
# EPOCH 24 improved validation micro f1-score to: 0.6651207109635178
# PRINTING TEST MICRO F1-SCORE: 0.6840319440232415
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 96.9288s
# -----------------------------------------------
#
# EPOCH 25 improved validation micro f1-score to: 0.672978288608955
# PRINTING TEST MICRO F1-SCORE: 0.6907631239367568
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 107.8695s
# -----------------------------------------------
#
# EPOCH 26 did not improve validation micro f1-score
# Seconds taken for this epoch: 104.8906s
# -----------------------------------------------
#
# EPOCH 27 improved validation micro f1-score to: 0.6783413164400495
# PRINTING TEST MICRO F1-SCORE: 0.6982698899675212
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 98.4772s
# -----------------------------------------------
#
# EPOCH 28 improved validation micro f1-score to: 0.680941653059959
# PRINTING TEST MICRO F1-SCORE: 0.7003680184097038
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 100.3883s
# -----------------------------------------------
#
# EPOCH 29 improved validation micro f1-score to: 0.6859234036645774
# PRINTING TEST MICRO F1-SCORE: 0.7072237375731256
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 103.1939s
# -----------------------------------------------
#
# EPOCH 30 improved validation micro f1-score to: 0.6867088371537905
# PRINTING TEST MICRO F1-SCORE: 0.7059095065975699
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 103.9848s
# -----------------------------------------------
#
# EPOCH 31 did not improve validation micro f1-score
# Seconds taken for this epoch: 100.6755s
# -----------------------------------------------
#
# EPOCH 32 improved validation micro f1-score to: 0.6949238712495811
# PRINTING TEST MICRO F1-SCORE: 0.7158640220390529
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 111.8079s
# -----------------------------------------------
#
# EPOCH 33 did not improve validation micro f1-score
# Seconds taken for this epoch: 99.6168s
# -----------------------------------------------
#
# EPOCH 34 improved validation micro f1-score to: 0.7001974917967158
# PRINTING TEST MICRO F1-SCORE: 0.7223716665475084
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 105.2464s
# -----------------------------------------------
#
# EPOCH 35 improved validation micro f1-score to: 0.7020822566711735
# PRINTING TEST MICRO F1-SCORE: 0.7248858701703597
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 101.4380s
# -----------------------------------------------
#
# EPOCH 36 improved validation micro f1-score to: 0.7063464042610541
# PRINTING TEST MICRO F1-SCORE: 0.7294713123397453
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 99.5886s
# -----------------------------------------------
#
# EPOCH 37 improved validation micro f1-score to: 0.711971428082667
# PRINTING TEST MICRO F1-SCORE: 0.7349839929764196
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 102.3752s
# -----------------------------------------------
#
# EPOCH 38 improved validation micro f1-score to: 0.7136843020607077
# PRINTING TEST MICRO F1-SCORE: 0.737524011392992
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 109.5178s
# -----------------------------------------------
#
# EPOCH 39 improved validation micro f1-score to: 0.7154287308691504
# PRINTING TEST MICRO F1-SCORE: 0.7397089021875255
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 96.3789s
# -----------------------------------------------
#
# EPOCH 40 improved validation micro f1-score to: 0.7162532866323054
# PRINTING TEST MICRO F1-SCORE: 0.7398422160508022
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 99.4323s
# -----------------------------------------------
#
# EPOCH 41 did not improve validation micro f1-score
# Seconds taken for this epoch: 98.4415s
# -----------------------------------------------
#
# EPOCH 42 did not improve validation micro f1-score
# Seconds taken for this epoch: 98.7877s
# -----------------------------------------------
#
# EPOCH 43 improved validation micro f1-score to: 0.7201717149455245
# PRINTING TEST MICRO F1-SCORE: 0.7449275686559651
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 100.5513s
# -----------------------------------------------
#
# EPOCH 44 improved validation micro f1-score to: 0.7274164196555176
# PRINTING TEST MICRO F1-SCORE: 0.7528182604942606
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 105.2720s
# -----------------------------------------------
#
# EPOCH 45 did not improve validation micro f1-score
# Seconds taken for this epoch: 97.5458s
# -----------------------------------------------
#
# EPOCH 46 improved validation micro f1-score to: 0.728297786141328
# PRINTING TEST MICRO F1-SCORE: 0.7555487700991487
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 101.2768s
# -----------------------------------------------
#
# EPOCH 47 did not improve validation micro f1-score
# Seconds taken for this epoch: 101.6817s
# -----------------------------------------------
#
# EPOCH 48 improved validation micro f1-score to: 0.7327573824430099
# PRINTING TEST MICRO F1-SCORE: 0.7597533366971944
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 100.1827s
# -----------------------------------------------
#
# EPOCH 49 improved validation micro f1-score to: 0.7356043901212675
# PRINTING TEST MICRO F1-SCORE: 0.761581723578983
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 101.5028s
# -----------------------------------------------
#
# EPOCH 50 improved validation micro f1-score to: 0.7394592183411235
# PRINTING TEST MICRO F1-SCORE: 0.7660773039235489
# SAVING MODEL to ind_model.pt
# Seconds taken for this epoch: 102.2920s
# -----------------------------------------------

# %% [markdown]
# ### Printing the final accuracy

# %%
ind_model.load_state_dict(torch.load('ind_model.pt'))
ind_model.eval()

with torch.no_grad():
    output = ind_model(nodes_test, adjacency_test)
    output_labeled = torch.where(output > 0.5, 1.0, 0.0)
    final_test_f1 = metrics.f1_score(output_labeled, y_test, average='micro')
    print(f'FINAL test micro F1-score is: {final_test_f1}')
# Out:
# FINAL test micro F1-score is: 0.7660773039235489

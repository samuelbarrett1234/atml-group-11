# %% [markdown]
# ### Prepare Relevant imports

# %%
import torch.optim as optim 
import torch.nn as nn
import torch_geometric as tg
import torch

import sys
import os

gat_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.append(gat_path)
from gat import GAT_Transductive

# %% [markdown]
# ### Preparing the data (the unique graph)

# %%
dataset = tg.datasets.Planetoid(root='data', name='Cora', split='full')
cora_dataloader = tg.loader.DataLoader(dataset)
cora_graph = next(iter(cora_dataloader))

nodes = cora_graph.x
y = cora_graph.y
adjacency_matrix = tg.utils.to_dense_adj(cora_graph.edge_index).squeeze(dim=0)

train_mask = cora_graph.train_mask
test_mask = cora_graph.test_mask
val_mask = cora_graph.val_mask

# %% [markdown]
# ### Preparing Model and Optimisers

# %%
# default values from GAT paper
lr = 0.005
weight_decay = 0.0005

trans_model = GAT_Transductive(1433, 7)
criterion = nn.CrossEntropyLoss()
optimiser = optim.Adam(trans_model.parameters(), 
                       lr=lr, 
                       weight_decay=weight_decay)

# %% [markdown]
# ### Running training with (very) simple early stopping with 20 epochs tolerance

# %%
tolerance = 0
best_val_accuracy = 0

for epoch in range(300):
    trans_model.train()
    
    output = trans_model(nodes, adjacency_matrix)
    loss = criterion(output[train_mask], y[train_mask])
    
    optimiser.zero_grad()
    loss.backward()
    optimiser.step()
    
    # compute validatio accuracy to fascilitate early stopping if needed
    trans_model.eval()
    with torch.no_grad():
        output = trans_model(nodes, adjacency_matrix)
        current_val_accuracy = (output[val_mask].argmax(dim=1) == y[val_mask]).sum().item() / val_mask.sum().item()
    
    if current_val_accuracy > best_val_accuracy:
        best_val_accuracy = current_val_accuracy
        tolerance = 0
        print(f'EPOCH {epoch+1} improved validation accuracy to: {current_val_accuracy}')
        
        with torch.no_grad():
            output = trans_model(nodes, adjacency_matrix)
            test_accuracy = (output[test_mask].argmax(dim=1) == y[test_mask]).sum().item() / test_mask.sum().item()
            print(f'PRINTING TEST ACCURACY: {test_accuracy}')
        print('SAVING MODEL to trans_model.pt')
        torch.save(trans_model.state_dict(), 'trans_model.pt')
        
    else:
        tolerance += 1
        print(f'EPOCH {epoch+1} did not improve validation accuracy')
        
        if tolerance == 19:
            print('Tolerance 20 epochs reached, exiting')
            break
    print('----------------------------------------------- \n')
# Out:
# EPOCH 1 improved validation accuracy to: 0.468
# PRINTING TEST ACCURACY: 0.454
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 2 improved validation accuracy to: 0.488
# PRINTING TEST ACCURACY: 0.484
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 3 improved validation accuracy to: 0.512
# PRINTING TEST ACCURACY: 0.506
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 4 improved validation accuracy to: 0.544
# PRINTING TEST ACCURACY: 0.535
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 5 improved validation accuracy to: 0.596
# PRINTING TEST ACCURACY: 0.59
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 6 improved validation accuracy to: 0.652
# PRINTING TEST ACCURACY: 0.643
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 7 improved validation accuracy to: 0.712
# PRINTING TEST ACCURACY: 0.705
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 8 improved validation accuracy to: 0.74
# PRINTING TEST ACCURACY: 0.747
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 9 improved validation accuracy to: 0.772
# PRINTING TEST ACCURACY: 0.788
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 10 improved validation accuracy to: 0.798
# PRINTING TEST ACCURACY: 0.812
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 11 improved validation accuracy to: 0.818
# PRINTING TEST ACCURACY: 0.825
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 12 improved validation accuracy to: 0.836
# PRINTING TEST ACCURACY: 0.833
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 13 improved validation accuracy to: 0.84
# PRINTING TEST ACCURACY: 0.834
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 14 improved validation accuracy to: 0.842
# PRINTING TEST ACCURACY: 0.84
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 15 improved validation accuracy to: 0.852
# PRINTING TEST ACCURACY: 0.847
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 16 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 17 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 18 improved validation accuracy to: 0.854
# PRINTING TEST ACCURACY: 0.859
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 19 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 20 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 21 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 22 improved validation accuracy to: 0.86
# PRINTING TEST ACCURACY: 0.866
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 23 improved validation accuracy to: 0.862
# PRINTING TEST ACCURACY: 0.864
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 24 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 25 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 26 improved validation accuracy to: 0.864
# PRINTING TEST ACCURACY: 0.866
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 27 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 28 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 29 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 30 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 31 improved validation accuracy to: 0.868
# PRINTING TEST ACCURACY: 0.861
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 32 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 33 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 34 improved validation accuracy to: 0.872
# PRINTING TEST ACCURACY: 0.862
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 35 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 36 improved validation accuracy to: 0.874
# PRINTING TEST ACCURACY: 0.866
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 37 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 38 improved validation accuracy to: 0.876
# PRINTING TEST ACCURACY: 0.87
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 39 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 40 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 41 improved validation accuracy to: 0.878
# PRINTING TEST ACCURACY: 0.873
# SAVING MODEL to trans_model.pt
# -----------------------------------------------
#
# EPOCH 42 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 43 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 44 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 45 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 46 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 47 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 48 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 49 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 50 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 51 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 52 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 53 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 54 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 55 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 56 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 57 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 58 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 59 did not improve validation accuracy
# -----------------------------------------------
#
# EPOCH 60 did not improve validation accuracy
# Tolerance 20 epochs reached, exiting

# %% [markdown]
# ### Printing the final accuracy

# %%
trans_model.load_state_dict(torch.load('trans_model.pt'))
trans_model.eval()

with torch.no_grad():
    output = trans_model(nodes, adjacency_matrix)
    final_test_accuracy = (output[test_mask].argmax(dim=1) == y[test_mask]).sum().item() / test_mask.sum().item()
    print(f'FINAL test accuracy is: {final_test_accuracy}')
# Out:
# FINAL test accuracy is: 0.873
